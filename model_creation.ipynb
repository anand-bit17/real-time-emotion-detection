# %% [markdown]
# Emotion_detection_course

# %%
import matplotlib.pyplot as plt 
from glob import glob
import cv2
import random
import os
# %matplotlib inline

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dense, Input,Dropout,Flatten,Conv2D
from tensorflow.keras.layers import BatchNormalization,Activation, MaxPooling2D
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.utils import plot_model


from IPython.display import SVG, Image
import tensorflow as tf 
print("tensorflow version:", tf.__version__)
# Out:
# tensorflow version: 2.15.0

# %% [markdown]
# Exploring Dataset

# %%
images = glob("train/**/**")
for i in range(9):
    image = random.choice(images)
    plt.figure(figsize=(12,12))
    plt.subplot(331+i)
    plt.imshow(cv2.imread(image));plt.axis('off')

# %% [markdown]
# **preparing data for training

# %%
img_size=48
batch_size=64
datagen_train = ImageDataGenerator()
train_generator = datagen_train.flow_from_directory("train/",
                                                    target_size= (img_size,img_size),
                                                    color_mode="grayscale",
                                                    batch_size=batch_size,
                                                    class_mode ="categorical",
                                                    shuffle=True)

datagen_validation= ImageDataGenerator()
validation_generator = datagen_validation.flow_from_directory("test/",
                                                              target_size=(img_size, img_size),
                                                              color_mode="grayscale",
                                                              batch_size=batch_size,
                                                              class_mode="categorical",
                                                              shuffle=False)
# Out:
# Found 28709 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.

# %% [markdown]
# Defining Model

# %%
def Convolution(input_tensor, filters, kernel_size):
    x = Conv2D(filters = filters, kernel_size = kernel_size, padding = "same")(input_tensor)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling2D(pool_size = (2,2))(x)
    x = Dropout(0.25)(x)
    
    return x

# %%
def Dense_f(input_tensor, nodes):
    x = Dense(nodes)(input_tensor)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Dropout(0.25)(x)
    
    return x

# %%
def model_fer(input_shape):
    inputs = Input(input_shape)
    conv_1 = Convolution(inputs,32,(3,3))
    conv_2 = Convolution(conv_1,64,(5,5))
    conv_3 = Convolution(conv_2,128,(3,3))

    flatten = Flatten()(conv_3)
    
    dense_1 = Dense_f(flatten,256)

    output  = Dense(7, activation="softmax")(dense_1)
    model  =  Model(inputs=[inputs],outputs = [output])
    
    model.compile(loss=['categorical_crossentropy'] , optimizer = 'adam' , metrics =["accuracy"])

    return model

# %%
model = model_fer((48,48,1))
model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 48, 48, 1)]       0
#
#  conv2d_3 (Conv2D)           (None, 48, 48, 32)        320
#
#  batch_normalization_4 (Bat  (None, 48, 48, 32)        128
#  chNormalization)
#
#  activation_4 (Activation)   (None, 48, 48, 32)        0
#
#  max_pooling2d_3 (MaxPoolin  (None, 24, 24, 32)        0
#  g2D)
#
#  dropout_4 (Dropout)         (None, 24, 24, 32)        0
#
#  conv2d_4 (Conv2D)           (None, 24, 24, 64)        51264
#
#  batch_normalization_5 (Bat  (None, 24, 24, 64)        256
#  chNormalization)
#
#  activation_5 (Activation)   (None, 24, 24, 64)        0
#
#  max_pooling2d_4 (MaxPoolin  (None, 12, 12, 64)        0
#  g2D)
#
#  dropout_5 (Dropout)         (None, 12, 12, 64)        0
#
#  conv2d_5 (Conv2D)           (None, 12, 12, 128)       73856
#
#  batch_normalization_6 (Bat  (None, 12, 12, 128)       512
#  chNormalization)
#
#  activation_6 (Activation)   (None, 12, 12, 128)       0
#
#  max_pooling2d_5 (MaxPoolin  (None, 6, 6, 128)         0
#  g2D)
#
#  dropout_6 (Dropout)         (None, 6, 6, 128)         0
#
#  flatten_1 (Flatten)         (None, 4608)              0
#
#  dense_2 (Dense)             (None, 256)               1179904
#
#  batch_normalization_7 (Bat  (None, 256)               1024
#  chNormalization)
#
#  activation_7 (Activation)   (None, 256)               0
#
#  dropout_7 (Dropout)         (None, 256)               0
#
#  dense_3 (Dense)             (None, 7)                 1799
#
# =================================================================
# Total params: 1309063 (4.99 MB)
# Trainable params: 1308103 (4.99 MB)
# Non-trainable params: 960 (3.75 KB)
# _________________________________________________________________

# %% [markdown]
# Intializing the model

# %%
epochs = 15
steps_per_epoch = train_generator.n//train_generator.batch_size
validation_steps = validation_generator.n//validation_generator.batch_size

checkpoint = ModelCheckpoint("model_weights.h5", monitor  ='val_accuracy', save_weights_only = True, mode = 'max', verbose =1)
callbacks = [checkpoint]

# %% [markdown]
# TRANING THE MODEL

# %%
history = model.fit(
    x=train_generator,
    steps_per_epoch=steps_per_epoch,
    epochs = epochs,
    validation_data = validation_generator,
    validation_steps = validation_steps,
    callbacks = callbacks)
# Out:
# Epoch 1/15
# WARNING:tensorflow:From c:\Users\hp\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Users\hp\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 448/448 [==============================] - ETA: 0s - loss: 1.6686 - accuracy: 0.3671
# Epoch 1: saving model to model_weights.h5
# 448/448 [==============================] - 640s 1s/step - loss: 1.6686 - accuracy: 0.3671 - val_loss: 1.5196 - val_accuracy: 0.4051
# Epoch 2/15
# 448/448 [==============================] - ETA: 0s - loss: 1.3774 - accuracy: 0.4745
# Epoch 2: saving model to model_weights.h5
# 448/448 [==============================] - 177s 395ms/step - loss: 1.3774 - accuracy: 0.4745 - val_loss: 1.3043 - val_accuracy: 0.4961
# Epoch 3/15
# 448/448 [==============================] - ETA: 0s - loss: 1.2637 - accuracy: 0.5202
# Epoch 3: saving model to model_weights.h5
# 448/448 [==============================] - 47s 105ms/step - loss: 1.2637 - accuracy: 0.5202 - val_loss: 1.4092 - val_accuracy: 0.4707
# Epoch 4/15
# 448/448 [==============================] - ETA: 0s - loss: 1.1992 - accuracy: 0.5434
# Epoch 4: saving model to model_weights.h5
# 448/448 [==============================] - 47s 105ms/step - loss: 1.1992 - accuracy: 0.5434 - val_loss: 1.2380 - val_accuracy: 0.5286
# Epoch 5/15
# 448/448 [==============================] - ETA: 0s - loss: 1.1384 - accuracy: 0.5690
# Epoch 5: saving model to model_weights.h5
# 448/448 [==============================] - 48s 106ms/step - loss: 1.1384 - accuracy: 0.5690 - val_loss: 1.1993 - val_accuracy: 0.5432
# Epoch 6/15
# 448/448 [==============================] - ETA: 0s - loss: 1.0914 - accuracy: 0.5881
# Epoch 6: saving model to model_weights.h5
# 448/448 [==============================] - 360s 806ms/step - loss: 1.0914 - accuracy: 0.5881 - val_loss: 1.1400 - val_accuracy: 0.5679
# Epoch 7/15
# 448/448 [==============================] - ETA: 0s - loss: 1.0528 - accuracy: 0.6049
# Epoch 7: saving model to model_weights.h5
# 448/448 [==============================] - 454s 1s/step - loss: 1.0528 - accuracy: 0.6049 - val_loss: 1.1833 - val_accuracy: 0.5586
# Epoch 8/15
# 448/448 [==============================] - ETA: 0s - loss: 1.0051 - accuracy: 0.6226
# Epoch 8: saving model to model_weights.h5
# 448/448 [==============================] - 120s 268ms/step - loss: 1.0051 - accuracy: 0.6226 - val_loss: 1.2006 - val_accuracy: 0.5487
# Epoch 9/15
# 448/448 [==============================] - ETA: 0s - loss: 0.9687 - accuracy: 0.6376
# Epoch 9: saving model to model_weights.h5
# 448/448 [==============================] - 46s 103ms/step - loss: 0.9687 - accuracy: 0.6376 - val_loss: 1.2682 - val_accuracy: 0.5410
# Epoch 10/15
# 448/448 [==============================] - ETA: 0s - loss: 0.9304 - accuracy: 0.6521
# Epoch 10: saving model to model_weights.h5
# 448/448 [==============================] - 146s 326ms/step - loss: 0.9304 - accuracy: 0.6521 - val_loss: 1.1071 - val_accuracy: 0.5872
# Epoch 11/15
# 448/448 [==============================] - ETA: 0s - loss: 0.8934 - accuracy: 0.6629
# Epoch 11: saving model to model_weights.h5
# 448/448 [==============================] - 62s 138ms/step - loss: 0.8934 - accuracy: 0.6629 - val_loss: 1.0931 - val_accuracy: 0.5992
# Epoch 12/15
# 448/448 [==============================] - ETA: 0s - loss: 0.8522 - accuracy: 0.6817
# Epoch 12: saving model to model_weights.h5
# 448/448 [==============================] - 45s 101ms/step - loss: 0.8522 - accuracy: 0.6817 - val_loss: 1.1189 - val_accuracy: 0.5944
# Epoch 13/15
# 448/448 [==============================] - ETA: 0s - loss: 0.8163 - accuracy: 0.6975
# Epoch 13: saving model to model_weights.h5
# 448/448 [==============================] - 47s 106ms/step - loss: 0.8163 - accuracy: 0.6975 - val_loss: 1.0714 - val_accuracy: 0.6104
# Epoch 14/15
# 448/448 [==============================] - ETA: 0s - loss: 0.7828 - accuracy: 0.7127
# Epoch 14: saving model to model_weights.h5
# 448/448 [==============================] - 45s 100ms/step - loss: 0.7828 - accuracy: 0.7127 - val_loss: 1.2058 - val_accuracy: 0.5658
# Epoch 15/15
# 448/448 [==============================] - ETA: 0s - loss: 0.7469 - accuracy: 0.7248
# Epoch 15: saving model to model_weights.h5
# 448/448 [==============================] - 45s 101ms/step - loss: 0.7469 - accuracy: 0.7248 - val_loss: 1.1306 - val_accuracy: 0.6006

# %% [markdown]
# MODEL EVALUATION

# %%
model.evaluate(validation_generator)
# Out:
# 113/113 [==============================] - 8s 67ms/step - loss: 1.1299 - accuracy: 0.6007
# [1.129854440689087, 0.600724458694458]

# %% [markdown]
# plotting loss

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.legend(['Train','Validation'],loc = 'upper left')
plt.subplots_adjust(top=1.0,bottom=0.0,right =0.95,left=0.0,hspace=0.25,wspace=0.35)

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.legend(['Train','Validation'],loc = 'upper left')
plt.subplots_adjust(top=1.0,bottom=0.0,right =0.95,left=0.0,hspace=0.25,wspace=0.35)

# %% [markdown]
# SAVING MODEL

# %%
model_json = model.to_json()
with open("model_a.json","w") as json_file:
    json_file.write(model_json)
